# %% [markdown]
# # Functions
# - What is aFunction?
# - Why use a Function?
# - Defining a Function
# - Calling a Function
# - Returning a Value
# - Parameter vs Argument
# - Types of Arguments
#   - Position
#   - Keyword
#   - Position-only Argument
#   - Keyword-only Argument
#   - dsf
# - Recursion
# - Lambda Function
# - Global and Local Variables
